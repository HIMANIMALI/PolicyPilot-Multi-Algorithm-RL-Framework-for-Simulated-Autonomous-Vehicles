# %% [markdown]
# ## Final Project

# %%
# !pip install swig
# !pip install "gymnasium[box2d]"
# Out:
# Collecting swig
#   Downloading swig-4.3.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (3.5 kB)
# Downloading swig-4.3.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 19.4 MB/s eta 0:00:00
# Installing collected packages: swig
# Successfully installed swig-4.3.1
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.11/dist-packages (1.1.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (4.13.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (0.0.4)
# Collecting box2d-py==2.3.5 (from gymnasium[box2d])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (2.6.1)
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (4.3.1)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp311-cp311-linux_x86_64.whl size=2379364 sha256=8ea197a24f64487cb8666a8c4c93cc87aac9c1a214d2e3e942b8478046e15be0
#   Stored in directory: /root/.cache/pip/wheels/ab/f1/0c/d56f4a2bdd12bae0a0693ec33f2f0daadb5eb9753c78fa5308
# Successfully built box2d-py
# Installing collected packages: box2d-py
# Successfully installed box2d-py-2.3.5

# %% [markdown]
# ### Testing the environment

# %%
import gymnasium as gym



env = gym.make("CarRacing-v3", render_mode="human")
obs, _ = env.reset()

for i in range(10000):
    action = env.action_space.sample()
    obs, reward, terminated, truncated, _ = env.step(action)

    if terminated or truncated:
        break

env.close()

# %% [markdown]
# ### Building agents and training modules

# %%
import gymnasium as gym # type: ignore
import numpy as np # type: ignore
from collections import deque
import random
import torch # type: ignore
import torch.nn as nn # type: ignore
import torch.optim as optim # type: ignore
import pickle
import time

import matplotlib.pyplot as plt # type: ignore
import cv2 # type: ignore

from collections import deque
import imageio # type: ignore

torch.backends.cudnn.benchmark = True


device = torch.device("cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu")



actions = [ #tried diff things nothing changed, this version supporting steering plus accelration in one action
    np.array([0.0, 0.0, 0.0]),
    np.array([0.0, 1.0, 0.0]),
    np.array([-1.0, 1.0, 0.0]),
    np.array([1.0, 1.0, 0.0]),
    np.array([0.0, 0.0, 0.8]),
]

# %% [markdown]
# ## pre-processing

# %%
class frame_stacker:

    def __init__(self, stack=4):

        self.stack = stack
        self.frames = deque([], maxlen=stack)

    def reset(self, obs):

        frame = self.pre_process(obs)

        for i in range(self.stack):

            self.frames.append(frame)

        return np.stack(self.frames, axis=0)

    def step(self, obs):

        frame = self.pre_process(obs)
        self.frames.append(frame)
        return np.stack(self.frames, axis=0)

    def pre_process(self, obs):

        gray = cv2.cvtColor(obs, cv2.COLOR_RGB2GRAY)
        resized = cv2.resize(gray, (84, 84), interpolation=cv2.INTER_AREA)
        return  resized/ 255.0
    
class replay_buffer:

    def __init__(self, capacity):

        self.buffer = deque(maxlen=capacity)

    def add(self, s, a, r, s_, d):

        self.buffer.append((s, a, r, s_, d))

    def sample(self, batch_size):

        return random.sample(self.buffer, batch_size)

# %% [markdown]
# ## Network building

# %%
class cnn(nn.Module):

    def __init__(self, no_of_actions):

        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(4, 32, kernel_size=8, stride=4), nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2), nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1), nn.ReLU()
        )
        self.fc = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64 * 7 * 7, 512), nn.ReLU(),
            nn.Linear(512, no_of_actions)
        )

    def forward(self, x):
        x = x.squeeze(1)
        return self.fc(self.conv(x))






class q_agent:

#changing parameters didnt yield better results, tried buffer_zse = 1000 and 10000 and batch_sizes = 64, 128, 256
    def __init__(self, learning_rate=1e-4, gamma=0.99, epsilon=1.0, epsilon_min = 0.05, epsilon_decay=100000, buffer_size=10000, batch_size=64):


        self.batch_size = batch_size
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay
        self.steps_done = 0

        self.q_net = cnn(len(actions)).to(device)
        self.target_net = cnn(len(actions)).to(device)
        self.target_net.load_state_dict(self.q_net.state_dict())
        self.optimizer = optim.Adam(self.q_net.parameters(),lr = learning_rate)

        self.buffer = replay_buffer(buffer_size)

    def selected_action(self, state):

        self.steps_done += 1

        self.epsilon = max(self.epsilon_min, self.epsilon - (1.0 - self.epsilon_min) / self.epsilon_decay)


        if np.random.rand() < self.epsilon:
            return random.randrange(len(actions))
        state_tensor = torch.FloatTensor(state).unsqueeze(0).unsqueeze(0).to(device)
        with torch.no_grad():
            return self.q_net(state_tensor).argmax().item()

    def update_target_network(self):
        self.target_net.load_state_dict(self.q_net.state_dict())

# %% [markdown]
# ## defining agents, dqn and double dqn

# %%
class dqn_agent(q_agent):

    def learn(self):

        if len(self.buffer.buffer) < self.batch_size:
            return

        batch = self.buffer.sample(self.batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)

        states = torch.from_numpy(np.array(states)).float().unsqueeze(1).to(device)
        next_states = torch.from_numpy(np.array(next_states)).float().unsqueeze(1).to(device)
        actions = torch.tensor(actions).unsqueeze(1).to(device)
        rewards = torch.tensor(rewards).unsqueeze(1).to(device)
        dones = torch.tensor(dones).float().unsqueeze(1).to(device)

        q_values = self.q_net(states).gather(1, actions)

        q_values_next = self.target_net(next_states).max(1, keepdim=True).values

        targets = rewards + (self.gamma * q_values_next * (1 - dones))

        loss = nn.MSELoss()(q_values, targets)

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()




class double_dqn_agent(q_agent):

    def learn(self):

        if len(self.buffer.buffer) < self.batch_size:
            return

        batch = self.buffer.sample(self.batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)

        states = torch.from_numpy(np.array(states)).float().unsqueeze(1).to(device)
        next_states = torch.from_numpy(np.array(next_states)).float().unsqueeze(1).to(device)
        actions = torch.tensor(actions).unsqueeze(1).to(device)
        rewards = torch.tensor(rewards).unsqueeze(1).to(device)
        dones = torch.tensor(dones).float().unsqueeze(1).to(device)

        q_values = self.q_net(states).gather(1, actions)
        next_actions = self.q_net(next_states).argmax(1, keepdim=True)

        q_values_next = self.target_net(next_states).gather(1, next_actions)
        targets = rewards + (self.gamma * q_values_next * (1 - dones))

        loss = nn.MSELoss()(q_values, targets)

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

# %% [markdown]
# ## training the agent fucntion

# %%
def agent_training(agent, env, no_of_episodes=3000, action_repeat=4, target_update_freq=1000, save_path="dqn_agent.pt"):

    # env = gym.make("CarRacing-v3", render_mode=None)
    stacker = frame_stacker(4)
    episode_rewards = []

    for episode in range(no_of_episodes):

        obs, info = env.reset()
        state = stacker.reset(obs)
        episode_reward = 0
        done = False
        steps = 0

        while not done:

            action = agent.selected_action(state)
            cumulative_reward = 0

            for i in range(action_repeat):
                next_obs, reward, terminated, truncated, _ = env.step(actions[action])
                done = terminated or truncated
                cumulative_reward += reward
                if done:
                    break

            best_state = stacker.step(next_obs)
            agent.buffer.add(state, action, cumulative_reward, best_state, done)
            state = best_state
            episode_reward += cumulative_reward
            agent.learn()

            if steps % target_update_freq == 0:
                agent.update_target_network()
            steps += 1

        print(f"episode {episode} | reward: {episode_reward:.2f} | timestamp: {time.strftime('%H:%M:%S')} | epsilon: {agent.epsilon:.3f}")

        episode_rewards.append(episode_reward)

    torch.save(agent.q_net.state_dict(), save_path)
    env.close()
    return episode_rewards

# %% [markdown]
# ### module to evaulate trained agent

# %%
def agent_evaluation(agent_class, model_path):
    
    env = gym.make("CarRacing-v3", render_mode="rgb_array")
    device = torch.device("cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu")

    agent = agent_class()

    agent.q_net.load_state_dict(torch.load(model_path, map_location=device))
    agent.q_net.to(device)
    agent.q_net.eval()

    episode_rewards = []

    for episode in range(10):
        obs, info = env.reset()
        stacker = frame_stacker(4)
        state = stacker.reset(obs)

        total_reward = 0
        done = False

        while not done:

            with torch.no_grad():
                state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
                action = agent.q_net(state_tensor).argmax().item()
                
            obs, reward, terminated, truncated, info = env.step(actions[action])
            done = terminated or truncated
            state = stacker.step(obs)
            total_reward += reward

        print(f"episode {episode + 1}: reward = {total_reward:.2f}")
        episode_rewards.append(total_reward)

    print(f'avg reward : {sum(episode_rewards)/10}')

    env.close()
    
    plot_rewards(episode_rewards, label="dqn evaluatiion")




def plot_rewards(rewards, label="dqn"):
    plt.figure(figsize=(10, 4))
    plt.plot(rewards, label=label)
    plt.xlabel("Episode")
    plt.ylabel("Total Reward")
    plt.title("Episode Reward Over Time")
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# ### training and plotting rewards of episodes by dqn agent on the env

# %%
agent = dqn_agent()

env = gym.make("CarRacing-v3", render_mode=None)

rewards = agent_training(agent, env, save_path="dqn_agent.pt")

plot_rewards(rewards,label = "dqn")
# Out:
# episode 0 | reward: -48.15 | timestamp: 21:57:53 | epsilon: 0.998
# episode 1 | reward: -10.89 | timestamp: 21:58:08 | epsilon: 0.995
# episode 2 | reward: -38.36 | timestamp: 21:58:23 | epsilon: 0.993
# episode 3 | reward: -54.06 | timestamp: 21:58:38 | epsilon: 0.991
# episode 4 | reward: -117.29 | timestamp: 21:58:46 | epsilon: 0.989
# episode 5 | reward: -72.22 | timestamp: 21:59:00 | epsilon: 0.987
# episode 6 | reward: 12.73 | timestamp: 21:59:15 | epsilon: 0.984
# episode 7 | reward: -51.72 | timestamp: 21:59:30 | epsilon: 0.982
# episode 8 | reward: -8.50 | timestamp: 21:59:46 | epsilon: 0.980
# episode 9 | reward: 29.69 | timestamp: 22:00:01 | epsilon: 0.977
# episode 10 | reward: -59.18 | timestamp: 22:00:17 | epsilon: 0.975
# episode 11 | reward: -16.11 | timestamp: 22:00:32 | epsilon: 0.973
# episode 12 | reward: -37.73 | timestamp: 22:00:47 | epsilon: 0.970
# episode 13 | reward: -158.61 | timestamp: 22:01:01 | epsilon: 0.968
# episode 14 | reward: -33.55 | timestamp: 22:01:16 | epsilon: 0.966
# episode 15 | reward: -46.67 | timestamp: 22:01:31 | epsilon: 0.963
# episode 16 | reward: -73.42 | timestamp: 22:01:46 | epsilon: 0.961
# episode 17 | reward: -55.33 | timestamp: 22:02:01 | epsilon: 0.958
# episode 18 | reward: 26.44 | timestamp: 22:02:17 | epsilon: 0.956
# episode 19 | reward: 23.19 | timestamp: 22:02:32 | epsilon: 0.954
# episode 20 | reward: -51.37 | timestamp: 22:02:47 | epsilon: 0.951
# episode 21 | reward: -48.64 | timestamp: 22:03:03 | epsilon: 0.949
# episode 22 | reward: -1.36 | timestamp: 22:03:18 | epsilon: 0.947
# episode 23 | reward: -28.57 | timestamp: 22:03:33 | epsilon: 0.944
# episode 24 | reward: -42.45 | timestamp: 22:03:48 | epsilon: 0.942
# episode 25 | reward: -41.38 | timestamp: 22:04:04 | epsilon: 0.939
# episode 26 | reward: -74.07 | timestamp: 22:04:19 | epsilon: 0.937
# episode 27 | reward: -50.00 | timestamp: 22:04:34 | epsilon: 0.935
# episode 28 | reward: -37.50 | timestamp: 22:04:50 | epsilon: 0.932
# episode 29 | reward: -78.72 | timestamp: 22:05:05 | epsilon: 0.930
# episode 30 | reward: -23.34 | timestamp: 22:05:20 | epsilon: 0.928
# episode 31 | reward: -14.50 | timestamp: 22:05:35 | epsilon: 0.925
# episode 32 | reward: -57.14 | timestamp: 22:05:49 | epsilon: 0.923
# episode 33 | reward: -132.92 | timestamp: 22:05:57 | epsilon: 0.922
# episode 34 | reward: -127.94 | timestamp: 22:06:08 | epsilon: 0.920
# episode 35 | reward: -28.34 | timestamp: 22:06:24 | epsilon: 0.917
# episode 36 | reward: -58.20 | timestamp: 22:06:40 | epsilon: 0.915
# episode 37 | reward: -35.81 | timestamp: 22:06:55 | epsilon: 0.913
# episode 38 | reward: -25.08 | timestamp: 22:07:11 | epsilon: 0.910
# episode 39 | reward: -29.33 | timestamp: 22:07:26 | epsilon: 0.908
# episode 40 | reward: -82.39 | timestamp: 22:07:41 | epsilon: 0.906
# episode 41 | reward: 13.36 | timestamp: 22:07:56 | epsilon: 0.903
# episode 42 | reward: -102.66 | timestamp: 22:08:10 | epsilon: 0.901
# episode 43 | reward: -16.67 | timestamp: 22:08:26 | epsilon: 0.899
# episode 44 | reward: -44.44 | timestamp: 22:08:40 | epsilon: 0.896
# episode 45 | reward: -13.93 | timestamp: 22:08:55 | epsilon: 0.894
# episode 46 | reward: 19.86 | timestamp: 22:09:11 | epsilon: 0.891
# episode 47 | reward: -50.00 | timestamp: 22:09:25 | epsilon: 0.889
# episode 48 | reward: -0.00 | timestamp: 22:09:41 | epsilon: 0.887
# episode 49 | reward: -74.45 | timestamp: 22:09:55 | epsilon: 0.884
# episode 50 | reward: -43.40 | timestamp: 22:10:11 | epsilon: 0.882
# episode 51 | reward: -64.41 | timestamp: 22:10:25 | epsilon: 0.880
# episode 52 | reward: 5.84 | timestamp: 22:10:40 | epsilon: 0.877
# episode 53 | reward: -42.57 | timestamp: 22:10:55 | epsilon: 0.875
# episode 54 | reward: 22.45 | timestamp: 22:11:11 | epsilon: 0.872
# episode 55 | reward: 1.85 | timestamp: 22:11:27 | epsilon: 0.870
# episode 56 | reward: -46.13 | timestamp: 22:11:42 | epsilon: 0.868
# episode 57 | reward: -137.60 | timestamp: 22:11:54 | epsilon: 0.866
# episode 58 | reward: 9.68 | timestamp: 22:12:10 | epsilon: 0.863
# episode 59 | reward: -57.10 | timestamp: 22:12:25 | epsilon: 0.861
# episode 60 | reward: -24.01 | timestamp: 22:12:41 | epsilon: 0.859
# episode 61 | reward: -137.61 | timestamp: 22:12:51 | epsilon: 0.857
# episode 62 | reward: 5.84 | timestamp: 22:13:06 | epsilon: 0.854
# episode 63 | reward: -7.19 | timestamp: 22:13:23 | epsilon: 0.852
# episode 64 | reward: -129.83 | timestamp: 22:13:32 | epsilon: 0.851
# episode 65 | reward: -43.33 | timestamp: 22:13:47 | epsilon: 0.848
# episode 66 | reward: -6.81 | timestamp: 22:14:02 | epsilon: 0.846
# episode 67 | reward: -8.76 | timestamp: 22:14:18 | epsilon: 0.844
# episode 68 | reward: -64.16 | timestamp: 22:14:32 | epsilon: 0.841
# episode 69 | reward: -62.73 | timestamp: 22:14:48 | epsilon: 0.839
# episode 70 | reward: -59.63 | timestamp: 22:15:03 | epsilon: 0.836
# episode 71 | reward: -66.97 | timestamp: 22:15:18 | epsilon: 0.834
# episode 72 | reward: -39.93 | timestamp: 22:15:33 | epsilon: 0.832
# episode 73 | reward: -66.33 | timestamp: 22:15:49 | epsilon: 0.829
# episode 74 | reward: -25.00 | timestamp: 22:16:03 | epsilon: 0.827
# episode 75 | reward: -52.73 | timestamp: 22:16:18 | epsilon: 0.825
# episode 76 | reward: -26.05 | timestamp: 22:16:33 | epsilon: 0.822
# episode 77 | reward: -60.23 | timestamp: 22:16:49 | epsilon: 0.820
# episode 78 | reward: -9.09 | timestamp: 22:17:04 | epsilon: 0.817
# episode 79 | reward: -56.52 | timestamp: 22:17:19 | epsilon: 0.815
# episode 80 | reward: 25.93 | timestamp: 22:17:34 | epsilon: 0.813
# episode 81 | reward: -130.35 | timestamp: 22:17:43 | epsilon: 0.811
# episode 82 | reward: 172.73 | timestamp: 22:17:59 | epsilon: 0.809
# episode 83 | reward: -24.66 | timestamp: 22:18:14 | epsilon: 0.806
# episode 84 | reward: -30.93 | timestamp: 22:18:30 | epsilon: 0.804
# episode 85 | reward: -77.64 | timestamp: 22:18:45 | epsilon: 0.802
# episode 86 | reward: -47.71 | timestamp: 22:19:00 | epsilon: 0.799
# episode 87 | reward: -66.56 | timestamp: 22:19:16 | epsilon: 0.797
# episode 88 | reward: -25.60 | timestamp: 22:19:31 | epsilon: 0.795
# episode 89 | reward: -64.41 | timestamp: 22:19:47 | epsilon: 0.792
# episode 90 | reward: -28.29 | timestamp: 22:20:02 | epsilon: 0.790
# episode 91 | reward: -29.37 | timestamp: 22:20:17 | epsilon: 0.787
# episode 92 | reward: 22.11 | timestamp: 22:20:33 | epsilon: 0.785
# episode 93 | reward: -12.09 | timestamp: 22:20:48 | epsilon: 0.783
# episode 94 | reward: 3.55 | timestamp: 22:21:04 | epsilon: 0.780
# episode 95 | reward: -38.84 | timestamp: 22:21:20 | epsilon: 0.778
# episode 96 | reward: -16.11 | timestamp: 22:21:36 | epsilon: 0.776
# episode 97 | reward: -28.06 | timestamp: 22:21:51 | epsilon: 0.773
# episode 98 | reward: -18.60 | timestamp: 22:22:07 | epsilon: 0.771
# episode 99 | reward: -50.33 | timestamp: 22:22:22 | epsilon: 0.768
# episode 100 | reward: -1.36 | timestamp: 22:22:37 | epsilon: 0.766
# episode 101 | reward: -33.58 | timestamp: 22:22:52 | epsilon: 0.764
# episode 102 | reward: -10.45 | timestamp: 22:23:08 | epsilon: 0.761
# episode 103 | reward: -30.60 | timestamp: 22:23:23 | epsilon: 0.759
# episode 104 | reward: -25.68 | timestamp: 22:23:38 | epsilon: 0.757
# episode 105 | reward: -42.24 | timestamp: 22:23:54 | epsilon: 0.754
# episode 106 | reward: 53.31 | timestamp: 22:24:09 | epsilon: 0.752
# episode 107 | reward: -0.00 | timestamp: 22:24:24 | epsilon: 0.749
# episode 108 | reward: 67.22 | timestamp: 22:24:40 | epsilon: 0.747
# episode 109 | reward: -39.29 | timestamp: 22:24:55 | epsilon: 0.745
# episode 110 | reward: -57.98 | timestamp: 22:25:10 | epsilon: 0.742
# episode 111 | reward: -32.54 | timestamp: 22:25:25 | epsilon: 0.740
# episode 112 | reward: -14.75 | timestamp: 22:25:41 | epsilon: 0.738
# episode 113 | reward: -84.49 | timestamp: 22:25:55 | epsilon: 0.735
# episode 114 | reward: -6.81 | timestamp: 22:26:11 | epsilon: 0.733
# episode 115 | reward: -21.99 | timestamp: 22:26:26 | epsilon: 0.731
# episode 116 | reward: -28.57 | timestamp: 22:26:41 | epsilon: 0.728
# episode 117 | reward: 41.82 | timestamp: 22:26:57 | epsilon: 0.726
# episode 118 | reward: -28.57 | timestamp: 22:27:12 | epsilon: 0.723
# episode 119 | reward: -27.39 | timestamp: 22:27:27 | epsilon: 0.721
# episode 120 | reward: -9.41 | timestamp: 22:27:43 | epsilon: 0.719
# episode 121 | reward: -60.26 | timestamp: 22:27:57 | epsilon: 0.716
# episode 122 | reward: -70.48 | timestamp: 22:28:11 | epsilon: 0.714
# episode 123 | reward: -44.44 | timestamp: 22:28:26 | epsilon: 0.712
# episode 124 | reward: -44.64 | timestamp: 22:28:42 | epsilon: 0.709
# episode 125 | reward: -76.35 | timestamp: 22:28:57 | epsilon: 0.707
# episode 126 | reward: -54.02 | timestamp: 22:29:12 | epsilon: 0.704
# episode 127 | reward: -57.65 | timestamp: 22:29:28 | epsilon: 0.702
# episode 128 | reward: -29.63 | timestamp: 22:29:43 | epsilon: 0.700
# episode 129 | reward: -61.69 | timestamp: 22:29:59 | epsilon: 0.697
# episode 130 | reward: 43.36 | timestamp: 22:30:14 | epsilon: 0.695
# episode 131 | reward: -53.80 | timestamp: 22:30:30 | epsilon: 0.693
# episode 132 | reward: -127.54 | timestamp: 22:30:40 | epsilon: 0.691
# episode 133 | reward: 2.89 | timestamp: 22:30:55 | epsilon: 0.689
# episode 134 | reward: 2.27 | timestamp: 22:31:10 | epsilon: 0.686
# episode 135 | reward: -138.43 | timestamp: 22:31:23 | epsilon: 0.684
# episode 136 | reward: -18.15 | timestamp: 22:31:38 | epsilon: 0.682
# episode 137 | reward: -29.89 | timestamp: 22:31:53 | epsilon: 0.680
# episode 138 | reward: -8.77 | timestamp: 22:32:09 | epsilon: 0.677
# episode 139 | reward: -6.15 | timestamp: 22:32:24 | epsilon: 0.675
# episode 140 | reward: 11.49 | timestamp: 22:32:40 | epsilon: 0.672
# episode 141 | reward: 66.10 | timestamp: 22:32:55 | epsilon: 0.670
# episode 142 | reward: -17.27 | timestamp: 22:33:11 | epsilon: 0.668
# episode 143 | reward: -38.91 | timestamp: 22:33:27 | epsilon: 0.665
# episode 144 | reward: 60.00 | timestamp: 22:33:42 | epsilon: 0.663
# episode 145 | reward: -0.36 | timestamp: 22:33:58 | epsilon: 0.661
# episode 146 | reward: 40.30 | timestamp: 22:34:14 | epsilon: 0.658
# episode 147 | reward: 28.03 | timestamp: 22:34:30 | epsilon: 0.656
# episode 148 | reward: -41.61 | timestamp: 22:34:44 | epsilon: 0.653
# episode 149 | reward: 5.26 | timestamp: 22:35:01 | epsilon: 0.651
# episode 150 | reward: -61.90 | timestamp: 22:35:16 | epsilon: 0.649
# episode 151 | reward: -23.08 | timestamp: 22:35:32 | epsilon: 0.646
# episode 152 | reward: -72.32 | timestamp: 22:35:47 | epsilon: 0.644
# episode 153 | reward: -35.15 | timestamp: 22:36:02 | epsilon: 0.642
# episode 154 | reward: -26.83 | timestamp: 22:36:17 | epsilon: 0.639
# episode 155 | reward: -1.75 | timestamp: 22:36:33 | epsilon: 0.637
# episode 156 | reward: -6.57 | timestamp: 22:36:48 | epsilon: 0.634
# episode 157 | reward: -50.00 | timestamp: 22:37:04 | epsilon: 0.632
# episode 158 | reward: -67.55 | timestamp: 22:37:19 | epsilon: 0.630
# episode 159 | reward: -56.66 | timestamp: 22:37:35 | epsilon: 0.627
# episode 160 | reward: -159.77 | timestamp: 22:37:48 | epsilon: 0.625
# episode 161 | reward: -1.90 | timestamp: 22:38:04 | epsilon: 0.623
# episode 162 | reward: -39.87 | timestamp: 22:38:20 | epsilon: 0.620
# episode 163 | reward: 5.80 | timestamp: 22:38:36 | epsilon: 0.618
# episode 164 | reward: -53.56 | timestamp: 22:38:52 | epsilon: 0.616
# episode 165 | reward: -5.41 | timestamp: 22:39:07 | epsilon: 0.613
# episode 166 | reward: -40.56 | timestamp: 22:39:23 | epsilon: 0.611
# episode 167 | reward: -3.45 | timestamp: 22:39:39 | epsilon: 0.609
# episode 168 | reward: -142.14 | timestamp: 22:39:52 | epsilon: 0.607
# episode 169 | reward: -52.70 | timestamp: 22:40:07 | epsilon: 0.604
# episode 170 | reward: 36.99 | timestamp: 22:40:23 | epsilon: 0.602
# episode 171 | reward: -9.09 | timestamp: 22:40:38 | epsilon: 0.599
# episode 172 | reward: -30.00 | timestamp: 22:40:53 | epsilon: 0.597
# episode 173 | reward: -18.64 | timestamp: 22:41:09 | epsilon: 0.595
# episode 174 | reward: -7.28 | timestamp: 22:41:25 | epsilon: 0.592
# episode 175 | reward: -113.40 | timestamp: 22:41:36 | epsilon: 0.591
# episode 176 | reward: -65.52 | timestamp: 22:41:51 | epsilon: 0.588
# episode 177 | reward: -17.24 | timestamp: 22:42:08 | epsilon: 0.586
# episode 178 | reward: -60.84 | timestamp: 22:42:24 | epsilon: 0.583
# episode 179 | reward: -62.33 | timestamp: 22:42:39 | epsilon: 0.581
# episode 180 | reward: -42.65 | timestamp: 22:42:56 | epsilon: 0.579
# episode 181 | reward: -28.34 | timestamp: 22:43:12 | epsilon: 0.576
# episode 182 | reward: -66.33 | timestamp: 22:43:29 | epsilon: 0.574
# episode 183 | reward: -20.00 | timestamp: 22:43:45 | epsilon: 0.572
# episode 184 | reward: 33.08 | timestamp: 22:44:01 | epsilon: 0.569
# episode 185 | reward: -40.96 | timestamp: 22:44:18 | epsilon: 0.567
# episode 186 | reward: -58.33 | timestamp: 22:44:33 | epsilon: 0.564
# episode 187 | reward: -34.03 | timestamp: 22:44:49 | epsilon: 0.562
# episode 188 | reward: -144.25 | timestamp: 22:45:02 | epsilon: 0.560
# episode 189 | reward: -25.53 | timestamp: 22:45:18 | epsilon: 0.558
# episode 190 | reward: 10.74 | timestamp: 22:45:34 | epsilon: 0.555
# episode 191 | reward: -33.33 | timestamp: 22:45:49 | epsilon: 0.553
# episode 192 | reward: -12.09 | timestamp: 22:46:04 | epsilon: 0.551
# episode 193 | reward: -0.36 | timestamp: 22:46:20 | epsilon: 0.548
# episode 194 | reward: -33.75 | timestamp: 22:46:36 | epsilon: 0.546
# episode 195 | reward: 1.45 | timestamp: 22:46:52 | epsilon: 0.543
# episode 196 | reward: -29.29 | timestamp: 22:47:07 | epsilon: 0.541
# episode 197 | reward: -26.91 | timestamp: 22:47:23 | epsilon: 0.539
# episode 198 | reward: -55.02 | timestamp: 22:47:38 | epsilon: 0.536
# episode 199 | reward: -33.58 | timestamp: 22:47:53 | epsilon: 0.534
# episode 200 | reward: -49.09 | timestamp: 22:48:08 | epsilon: 0.532
# episode 201 | reward: -22.48 | timestamp: 22:48:24 | epsilon: 0.529
# episode 202 | reward: -16.38 | timestamp: 22:48:40 | epsilon: 0.527
# episode 203 | reward: -69.90 | timestamp: 22:48:55 | epsilon: 0.524
# episode 204 | reward: 39.93 | timestamp: 22:49:10 | epsilon: 0.522
# episode 205 | reward: -58.60 | timestamp: 22:49:26 | epsilon: 0.520
# episode 206 | reward: -2.62 | timestamp: 22:49:41 | epsilon: 0.517
# episode 207 | reward: -4.59 | timestamp: 22:49:57 | epsilon: 0.515
# episode 208 | reward: -25.37 | timestamp: 22:50:12 | epsilon: 0.513
# episode 209 | reward: -35.90 | timestamp: 22:50:28 | epsilon: 0.510
# episode 210 | reward: -78.33 | timestamp: 22:50:43 | epsilon: 0.508
# episode 211 | reward: -9.37 | timestamp: 22:50:59 | epsilon: 0.505
# episode 212 | reward: 9.22 | timestamp: 22:51:14 | epsilon: 0.503
# episode 213 | reward: 31.67 | timestamp: 22:51:30 | epsilon: 0.501
# episode 214 | reward: -31.60 | timestamp: 22:51:45 | epsilon: 0.498
# episode 215 | reward: -29.89 | timestamp: 22:52:01 | epsilon: 0.496
# episode 216 | reward: -22.85 | timestamp: 22:52:17 | epsilon: 0.494
# episode 217 | reward: -19.58 | timestamp: 22:52:32 | epsilon: 0.491
# episode 218 | reward: -24.81 | timestamp: 22:52:48 | epsilon: 0.489
# episode 219 | reward: 17.19 | timestamp: 22:53:03 | epsilon: 0.486
# episode 220 | reward: -25.80 | timestamp: 22:53:19 | epsilon: 0.484
# episode 221 | reward: -66.89 | timestamp: 22:53:34 | epsilon: 0.482
# episode 222 | reward: -46.24 | timestamp: 22:53:49 | epsilon: 0.479
# episode 223 | reward: 4.17 | timestamp: 22:54:05 | epsilon: 0.477
# episode 224 | reward: -39.39 | timestamp: 22:54:21 | epsilon: 0.475
# episode 225 | reward: -51.30 | timestamp: 22:54:36 | epsilon: 0.472
# episode 226 | reward: -64.07 | timestamp: 22:54:52 | epsilon: 0.470
# episode 227 | reward: -45.95 | timestamp: 22:55:07 | epsilon: 0.467
# episode 228 | reward: -116.22 | timestamp: 22:55:17 | epsilon: 0.466
# episode 229 | reward: -124.56 | timestamp: 22:55:29 | epsilon: 0.464
# episode 230 | reward: 6.38 | timestamp: 22:55:45 | epsilon: 0.462
# episode 231 | reward: -11.26 | timestamp: 22:56:01 | epsilon: 0.459
# episode 232 | reward: -66.22 | timestamp: 22:56:16 | epsilon: 0.457
# episode 233 | reward: -12.28 | timestamp: 22:56:32 | epsilon: 0.454
# episode 234 | reward: -5.59 | timestamp: 22:56:48 | epsilon: 0.452
# episode 235 | reward: 9.76 | timestamp: 22:57:04 | epsilon: 0.450
# episode 236 | reward: -33.57 | timestamp: 22:57:21 | epsilon: 0.447
# episode 237 | reward: -9.41 | timestamp: 22:57:37 | epsilon: 0.445
# episode 238 | reward: -37.09 | timestamp: 22:57:52 | epsilon: 0.443
# episode 239 | reward: -43.06 | timestamp: 22:58:08 | epsilon: 0.440
# episode 240 | reward: -9.41 | timestamp: 22:58:23 | epsilon: 0.438
# episode 241 | reward: 5.10 | timestamp: 22:58:40 | epsilon: 0.435
# episode 242 | reward: -12.75 | timestamp: 22:58:55 | epsilon: 0.433
# episode 243 | reward: -4.76 | timestamp: 22:59:11 | epsilon: 0.431
# episode 244 | reward: -64.63 | timestamp: 22:59:26 | epsilon: 0.428
# episode 245 | reward: 0.69 | timestamp: 22:59:42 | epsilon: 0.426
# episode 246 | reward: -67.74 | timestamp: 22:59:57 | epsilon: 0.424
# episode 247 | reward: -52.38 | timestamp: 23:00:12 | epsilon: 0.421
# episode 248 | reward: -158.31 | timestamp: 23:00:24 | epsilon: 0.419
# episode 249 | reward: 44.93 | timestamp: 23:00:39 | epsilon: 0.417
# episode 250 | reward: -47.19 | timestamp: 23:00:55 | epsilon: 0.415
# episode 251 | reward: -43.14 | timestamp: 23:01:11 | epsilon: 0.412
# episode 252 | reward: 44.69 | timestamp: 23:01:27 | epsilon: 0.410
# episode 253 | reward: -41.38 | timestamp: 23:01:42 | epsilon: 0.408
# episode 254 | reward: -102.31 | timestamp: 23:01:50 | epsilon: 0.406
# episode 255 | reward: -21.23 | timestamp: 23:02:06 | epsilon: 0.404
# episode 256 | reward: -61.41 | timestamp: 23:02:22 | epsilon: 0.402
# episode 257 | reward: -72.88 | timestamp: 23:02:37 | epsilon: 0.399
# episode 258 | reward: -55.17 | timestamp: 23:02:53 | epsilon: 0.397
# episode 259 | reward: -44.27 | timestamp: 23:03:09 | epsilon: 0.394
# episode 260 | reward: 4.48 | timestamp: 23:03:24 | epsilon: 0.392
# episode 261 | reward: 9.59 | timestamp: 23:03:40 | epsilon: 0.390
# episode 262 | reward: -76.43 | timestamp: 23:03:56 | epsilon: 0.387
# episode 263 | reward: -29.78 | timestamp: 23:04:13 | epsilon: 0.385
# episode 264 | reward: -56.11 | timestamp: 23:04:29 | epsilon: 0.383
# episode 265 | reward: -50.44 | timestamp: 23:04:45 | epsilon: 0.380
# episode 266 | reward: -81.07 | timestamp: 23:05:00 | epsilon: 0.378
# episode 267 | reward: -35.19 | timestamp: 23:05:17 | epsilon: 0.375
# episode 268 | reward: -16.35 | timestamp: 23:05:33 | epsilon: 0.373
# episode 269 | reward: -45.16 | timestamp: 23:05:49 | epsilon: 0.371
# episode 270 | reward: -10.96 | timestamp: 23:06:05 | epsilon: 0.368
# episode 271 | reward: -59.32 | timestamp: 23:06:21 | epsilon: 0.366
# episode 272 | reward: -75.78 | timestamp: 23:06:35 | epsilon: 0.364
# episode 273 | reward: -55.17 | timestamp: 23:06:51 | epsilon: 0.361
# episode 274 | reward: -33.57 | timestamp: 23:07:06 | epsilon: 0.359
# episode 275 | reward: -29.53 | timestamp: 23:07:23 | epsilon: 0.356
# episode 276 | reward: -3.78 | timestamp: 23:07:38 | epsilon: 0.354
# episode 277 | reward: -77.20 | timestamp: 23:07:54 | epsilon: 0.352
# episode 278 | reward: 9.97 | timestamp: 23:08:10 | epsilon: 0.349
# episode 279 | reward: -80.13 | timestamp: 23:08:25 | epsilon: 0.347
# episode 280 | reward: -67.27 | timestamp: 23:08:41 | epsilon: 0.345
# episode 281 | reward: -25.00 | timestamp: 23:08:56 | epsilon: 0.342
# episode 282 | reward: -8.13 | timestamp: 23:09:12 | epsilon: 0.340
# episode 283 | reward: -53.95 | timestamp: 23:09:29 | epsilon: 0.337
# episode 284 | reward: -45.95 | timestamp: 23:09:45 | epsilon: 0.335
# episode 285 | reward: -31.46 | timestamp: 23:10:01 | epsilon: 0.333
# episode 286 | reward: -65.78 | timestamp: 23:10:16 | epsilon: 0.330
# episode 287 | reward: -35.59 | timestamp: 23:10:32 | epsilon: 0.328
# episode 288 | reward: 11.50 | timestamp: 23:10:48 | epsilon: 0.326
# episode 289 | reward: -56.20 | timestamp: 23:11:03 | epsilon: 0.323
# episode 290 | reward: -61.29 | timestamp: 23:11:19 | epsilon: 0.321
# episode 291 | reward: 32.14 | timestamp: 23:11:34 | epsilon: 0.318
# episode 292 | reward: -58.76 | timestamp: 23:11:50 | epsilon: 0.316
# episode 293 | reward: -51.07 | timestamp: 23:12:06 | epsilon: 0.314
# episode 294 | reward: -14.56 | timestamp: 23:12:22 | epsilon: 0.311
# episode 295 | reward: -46.15 | timestamp: 23:12:38 | epsilon: 0.309
# episode 296 | reward: 1.35 | timestamp: 23:12:54 | epsilon: 0.307
# episode 297 | reward: 2.24 | timestamp: 23:13:11 | epsilon: 0.304
# episode 298 | reward: -36.40 | timestamp: 23:13:27 | epsilon: 0.302
# episode 299 | reward: -68.45 | timestamp: 23:13:42 | epsilon: 0.299
# episode 300 | reward: -3.70 | timestamp: 23:13:58 | epsilon: 0.297
# episode 301 | reward: -20.73 | timestamp: 23:14:14 | epsilon: 0.295
# episode 302 | reward: -32.48 | timestamp: 23:14:31 | epsilon: 0.292
# episode 303 | reward: 28.00 | timestamp: 23:14:47 | epsilon: 0.290
# episode 304 | reward: -12.09 | timestamp: 23:15:02 | epsilon: 0.288
# episode 305 | reward: -50.41 | timestamp: 23:15:18 | epsilon: 0.285
# episode 306 | reward: -2.10 | timestamp: 23:15:34 | epsilon: 0.283
# episode 307 | reward: -133.55 | timestamp: 23:15:44 | epsilon: 0.281
# episode 308 | reward: -0.37 | timestamp: 23:16:00 | epsilon: 0.279
# episode 309 | reward: -49.81 | timestamp: 23:16:16 | epsilon: 0.276
# episode 310 | reward: 39.62 | timestamp: 23:16:32 | epsilon: 0.274
# episode 311 | reward: 49.31 | timestamp: 23:16:48 | epsilon: 0.272
# episode 312 | reward: -39.72 | timestamp: 23:17:04 | epsilon: 0.269
# episode 313 | reward: -29.10 | timestamp: 23:17:20 | epsilon: 0.267
# episode 314 | reward: -26.67 | timestamp: 23:17:36 | epsilon: 0.265
# episode 315 | reward: -6.06 | timestamp: 23:17:52 | epsilon: 0.262
# episode 316 | reward: -54.25 | timestamp: 23:18:07 | epsilon: 0.260
# episode 317 | reward: -17.98 | timestamp: 23:18:24 | epsilon: 0.257
# episode 318 | reward: 11.91 | timestamp: 23:18:40 | epsilon: 0.255
# episode 319 | reward: -39.19 | timestamp: 23:18:56 | epsilon: 0.253
# episode 320 | reward: -29.29 | timestamp: 23:19:12 | epsilon: 0.250
# episode 321 | reward: 29.92 | timestamp: 23:19:27 | epsilon: 0.248
# episode 322 | reward: -42.24 | timestamp: 23:19:43 | epsilon: 0.246
# episode 323 | reward: -36.88 | timestamp: 23:19:58 | epsilon: 0.243
# episode 324 | reward: 34.33 | timestamp: 23:20:14 | epsilon: 0.241
# episode 325 | reward: -13.62 | timestamp: 23:20:30 | epsilon: 0.238
# episode 326 | reward: -3.23 | timestamp: 23:20:46 | epsilon: 0.236
# episode 327 | reward: -58.47 | timestamp: 23:21:01 | epsilon: 0.234
# episode 328 | reward: -40.07 | timestamp: 23:21:17 | epsilon: 0.231
# episode 329 | reward: -15.82 | timestamp: 23:21:32 | epsilon: 0.229
# episode 330 | reward: -60.61 | timestamp: 23:21:49 | epsilon: 0.227
# episode 331 | reward: -26.57 | timestamp: 23:22:04 | epsilon: 0.224
# episode 332 | reward: -21.45 | timestamp: 23:22:20 | epsilon: 0.222
# episode 333 | reward: 3.45 | timestamp: 23:22:36 | epsilon: 0.219
# episode 334 | reward: -22.81 | timestamp: 23:22:52 | epsilon: 0.217
# episode 335 | reward: -53.57 | timestamp: 23:23:07 | epsilon: 0.215
# episode 336 | reward: -28.57 | timestamp: 23:23:23 | epsilon: 0.212
# episode 337 | reward: 10.32 | timestamp: 23:23:39 | epsilon: 0.210
# episode 338 | reward: 21.41 | timestamp: 23:23:55 | epsilon: 0.208
# episode 339 | reward: -45.26 | timestamp: 23:24:11 | epsilon: 0.205
# episode 340 | reward: -56.23 | timestamp: 23:24:26 | epsilon: 0.203
# episode 341 | reward: -61.54 | timestamp: 23:24:43 | epsilon: 0.200
# episode 342 | reward: -41.18 | timestamp: 23:24:59 | epsilon: 0.198
# episode 343 | reward: -59.04 | timestamp: 23:25:15 | epsilon: 0.196
# episode 344 | reward: -39.29 | timestamp: 23:25:31 | epsilon: 0.193
# episode 345 | reward: -78.26 | timestamp: 23:25:47 | epsilon: 0.191
# episode 346 | reward: -2.78 | timestamp: 23:26:03 | epsilon: 0.189
# episode 347 | reward: -25.93 | timestamp: 23:26:19 | epsilon: 0.186
# episode 348 | reward: -77.71 | timestamp: 23:26:34 | epsilon: 0.184
# episode 349 | reward: -30.38 | timestamp: 23:26:51 | epsilon: 0.181
# episode 350 | reward: 50.17 | timestamp: 23:27:07 | epsilon: 0.179
# episode 351 | reward: -8.16 | timestamp: 23:27:23 | epsilon: 0.177
# episode 352 | reward: -128.94 | timestamp: 23:27:31 | epsilon: 0.175
# episode 353 | reward: -28.34 | timestamp: 23:27:47 | epsilon: 0.173
# episode 354 | reward: -50.17 | timestamp: 23:28:03 | epsilon: 0.171
# episode 355 | reward: 14.39 | timestamp: 23:28:19 | epsilon: 0.168
# episode 356 | reward: -31.90 | timestamp: 23:28:35 | epsilon: 0.166
# episode 357 | reward: 63.50 | timestamp: 23:28:50 | epsilon: 0.164
# episode 358 | reward: -53.49 | timestamp: 23:29:06 | epsilon: 0.161
# episode 359 | reward: -7.69 | timestamp: 23:29:22 | epsilon: 0.159
# episode 360 | reward: -19.46 | timestamp: 23:29:37 | epsilon: 0.156
# episode 361 | reward: -34.55 | timestamp: 23:29:53 | epsilon: 0.154
# episode 362 | reward: -0.34 | timestamp: 23:30:09 | epsilon: 0.152
# episode 363 | reward: -20.79 | timestamp: 23:30:25 | epsilon: 0.149
# episode 364 | reward: 6.11 | timestamp: 23:30:41 | epsilon: 0.147
# episode 365 | reward: 9.43 | timestamp: 23:30:57 | epsilon: 0.145
# episode 366 | reward: -28.33 | timestamp: 23:31:13 | epsilon: 0.142
# episode 367 | reward: -28.06 | timestamp: 23:31:28 | epsilon: 0.140
# episode 368 | reward: -64.74 | timestamp: 23:31:45 | epsilon: 0.137
# episode 369 | reward: 40.00 | timestamp: 23:32:01 | epsilon: 0.135
# episode 370 | reward: -26.05 | timestamp: 23:32:17 | epsilon: 0.133
# episode 371 | reward: -43.22 | timestamp: 23:32:34 | epsilon: 0.130
# episode 372 | reward: -18.10 | timestamp: 23:32:49 | epsilon: 0.128
# episode 373 | reward: -74.17 | timestamp: 23:33:05 | epsilon: 0.126
# episode 374 | reward: -29.88 | timestamp: 23:33:22 | epsilon: 0.123
# episode 375 | reward: -1.96 | timestamp: 23:33:39 | epsilon: 0.121
# episode 376 | reward: -36.24 | timestamp: 23:33:55 | epsilon: 0.118
# episode 377 | reward: -39.85 | timestamp: 23:34:11 | epsilon: 0.116
# episode 378 | reward: 10.41 | timestamp: 23:34:28 | epsilon: 0.114
# episode 379 | reward: -63.37 | timestamp: 23:34:43 | epsilon: 0.111
# episode 380 | reward: -21.23 | timestamp: 23:35:00 | epsilon: 0.109
# episode 381 | reward: -9.72 | timestamp: 23:35:16 | epsilon: 0.107
# episode 382 | reward: -42.24 | timestamp: 23:35:32 | epsilon: 0.104
# episode 383 | reward: -51.39 | timestamp: 23:35:48 | epsilon: 0.102
# episode 384 | reward: -11.44 | timestamp: 23:36:04 | epsilon: 0.099
# episode 385 | reward: -62.69 | timestamp: 23:36:21 | epsilon: 0.097
# episode 386 | reward: -25.57 | timestamp: 23:36:37 | epsilon: 0.095
# episode 387 | reward: -10.16 | timestamp: 23:36:53 | epsilon: 0.092
# episode 388 | reward: 46.85 | timestamp: 23:37:09 | epsilon: 0.090
# episode 389 | reward: -6.67 | timestamp: 23:37:25 | epsilon: 0.088
# episode 390 | reward: -16.32 | timestamp: 23:37:41 | epsilon: 0.085
# episode 391 | reward: -11.35 | timestamp: 23:37:57 | epsilon: 0.083
# episode 392 | reward: -78.12 | timestamp: 23:38:14 | epsilon: 0.080
# episode 393 | reward: -26.47 | timestamp: 23:38:30 | epsilon: 0.078
# episode 394 | reward: -33.99 | timestamp: 23:38:46 | epsilon: 0.076
# episode 395 | reward: -18.29 | timestamp: 23:39:02 | epsilon: 0.073
# episode 396 | reward: -11.59 | timestamp: 23:39:18 | epsilon: 0.071
# episode 397 | reward: -46.06 | timestamp: 23:39:34 | epsilon: 0.069
# episode 398 | reward: -59.60 | timestamp: 23:39:51 | epsilon: 0.066
# episode 399 | reward: -44.44 | timestamp: 23:40:07 | epsilon: 0.064
# episode 400 | reward: -17.97 | timestamp: 23:40:23 | epsilon: 0.061
# episode 401 | reward: -43.06 | timestamp: 23:40:39 | epsilon: 0.059
# episode 402 | reward: -48.45 | timestamp: 23:40:56 | epsilon: 0.057
# episode 403 | reward: -78.02 | timestamp: 23:41:11 | epsilon: 0.054
# episode 404 | reward: -41.94 | timestamp: 23:41:27 | epsilon: 0.052
# episode 405 | reward: -63.75 | timestamp: 23:41:44 | epsilon: 0.050
# episode 406 | reward: -36.03 | timestamp: 23:41:59 | epsilon: 0.050
# episode 407 | reward: -53.02 | timestamp: 23:42:16 | epsilon: 0.050
# episode 408 | reward: -53.07 | timestamp: 23:42:32 | epsilon: 0.050
# episode 409 | reward: -60.53 | timestamp: 23:42:48 | epsilon: 0.050
# episode 410 | reward: -47.04 | timestamp: 23:43:04 | epsilon: 0.050
# episode 411 | reward: -40.00 | timestamp: 23:43:20 | epsilon: 0.050
# episode 412 | reward: -50.18 | timestamp: 23:43:36 | epsilon: 0.050
# episode 413 | reward: -70.00 | timestamp: 23:43:52 | epsilon: 0.050
# episode 414 | reward: -59.18 | timestamp: 23:44:08 | epsilon: 0.050
# episode 415 | reward: 9.22 | timestamp: 23:44:24 | epsilon: 0.050
# episode 416 | reward: 23.19 | timestamp: 23:44:40 | epsilon: 0.050
# episode 417 | reward: -31.73 | timestamp: 23:44:56 | epsilon: 0.050
# episode 418 | reward: -48.39 | timestamp: 23:45:12 | epsilon: 0.050
# episode 419 | reward: -44.83 | timestamp: 23:45:28 | epsilon: 0.050
# episode 420 | reward: -19.73 | timestamp: 23:45:44 | epsilon: 0.050
# episode 421 | reward: -70.37 | timestamp: 23:45:59 | epsilon: 0.050
# episode 422 | reward: 2.56 | timestamp: 23:46:16 | epsilon: 0.050
# episode 423 | reward: -67.27 | timestamp: 23:46:31 | epsilon: 0.050
# episode 424 | reward: -35.71 | timestamp: 23:46:47 | epsilon: 0.050
# episode 425 | reward: -22.58 | timestamp: 23:47:04 | epsilon: 0.050
# episode 426 | reward: -55.65 | timestamp: 23:47:19 | epsilon: 0.050
# episode 427 | reward: -24.53 | timestamp: 23:47:35 | epsilon: 0.050
# episode 428 | reward: -5.80 | timestamp: 23:47:50 | epsilon: 0.050
# episode 429 | reward: -68.48 | timestamp: 23:48:07 | epsilon: 0.050
# episode 430 | reward: -71.06 | timestamp: 23:48:23 | epsilon: 0.050
# episode 431 | reward: -31.03 | timestamp: 23:48:38 | epsilon: 0.050
# episode 432 | reward: -12.55 | timestamp: 23:48:54 | epsilon: 0.050
# episode 433 | reward: 10.03 | timestamp: 23:49:10 | epsilon: 0.050
# episode 434 | reward: -36.36 | timestamp: 23:49:26 | epsilon: 0.050
# episode 435 | reward: 0.95 | timestamp: 23:49:42 | epsilon: 0.050
# episode 436 | reward: -45.76 | timestamp: 23:49:58 | epsilon: 0.050
# episode 437 | reward: -68.45 | timestamp: 23:50:13 | epsilon: 0.050
# episode 438 | reward: -59.18 | timestamp: 23:50:29 | epsilon: 0.050
# episode 439 | reward: -12.75 | timestamp: 23:50:45 | epsilon: 0.050
# episode 440 | reward: -29.45 | timestamp: 23:51:01 | epsilon: 0.050
# episode 441 | reward: -40.40 | timestamp: 23:51:17 | epsilon: 0.050
# episode 442 | reward: -79.04 | timestamp: 23:51:33 | epsilon: 0.050
# episode 443 | reward: 5.84 | timestamp: 23:51:49 | epsilon: 0.050
# episode 444 | reward: -25.00 | timestamp: 23:52:06 | epsilon: 0.050
# episode 445 | reward: 56.93 | timestamp: 23:52:22 | epsilon: 0.050
# episode 446 | reward: -38.93 | timestamp: 23:52:38 | epsilon: 0.050
# episode 447 | reward: -4.06 | timestamp: 23:52:54 | epsilon: 0.050
# episode 448 | reward: -124.66 | timestamp: 23:53:01 | epsilon: 0.050
# episode 449 | reward: -29.37 | timestamp: 23:53:17 | epsilon: 0.050
# episode 450 | reward: -33.58 | timestamp: 23:53:33 | epsilon: 0.050
# episode 451 | reward: -72.88 | timestamp: 23:53:49 | epsilon: 0.050
# episode 452 | reward: -41.18 | timestamp: 23:54:05 | epsilon: 0.050
# episode 453 | reward: -55.06 | timestamp: 23:54:20 | epsilon: 0.050
# episode 454 | reward: -37.16 | timestamp: 23:54:37 | epsilon: 0.050
# episode 455 | reward: -12.59 | timestamp: 23:54:53 | epsilon: 0.050
# episode 456 | reward: -59.60 | timestamp: 23:55:09 | epsilon: 0.050
# episode 457 | reward: -22.30 | timestamp: 23:55:25 | epsilon: 0.050
# episode 458 | reward: -74.19 | timestamp: 23:55:42 | epsilon: 0.050
# episode 459 | reward: -22.54 | timestamp: 23:55:58 | epsilon: 0.050
# episode 460 | reward: -31.82 | timestamp: 23:56:14 | epsilon: 0.050
# episode 461 | reward: -47.19 | timestamp: 23:56:30 | epsilon: 0.050
# episode 462 | reward: -48.95 | timestamp: 23:56:46 | epsilon: 0.050
# episode 463 | reward: -72.66 | timestamp: 23:57:02 | epsilon: 0.050
# episode 464 | reward: -31.82 | timestamp: 23:57:18 | epsilon: 0.050
# episode 465 | reward: -35.98 | timestamp: 23:57:34 | epsilon: 0.050
# episode 466 | reward: -56.67 | timestamp: 23:57:51 | epsilon: 0.050
# episode 467 | reward: -73.24 | timestamp: 23:58:06 | epsilon: 0.050
# episode 468 | reward: -37.06 | timestamp: 23:58:22 | epsilon: 0.050
# episode 469 | reward: -54.23 | timestamp: 23:58:38 | epsilon: 0.050
# episode 470 | reward: 50.20 | timestamp: 23:58:54 | epsilon: 0.050
# episode 471 | reward: -48.10 | timestamp: 23:59:11 | epsilon: 0.050
# episode 472 | reward: -75.69 | timestamp: 23:59:27 | epsilon: 0.050
# episode 473 | reward: -63.58 | timestamp: 23:59:43 | epsilon: 0.050
# episode 474 | reward: -71.63 | timestamp: 23:59:59 | epsilon: 0.050
# episode 475 | reward: -51.46 | timestamp: 00:00:15 | epsilon: 0.050
# episode 476 | reward: -26.91 | timestamp: 00:00:31 | epsilon: 0.050
# episode 477 | reward: -37.24 | timestamp: 00:00:46 | epsilon: 0.050
# episode 478 | reward: -81.48 | timestamp: 00:01:02 | epsilon: 0.050
# episode 479 | reward: -15.49 | timestamp: 00:01:18 | epsilon: 0.050
# episode 480 | reward: -55.48 | timestamp: 00:01:34 | epsilon: 0.050
# episode 481 | reward: -62.12 | timestamp: 00:01:50 | epsilon: 0.050
# episode 482 | reward: -76.74 | timestamp: 00:02:06 | epsilon: 0.050
# episode 483 | reward: -66.22 | timestamp: 00:02:22 | epsilon: 0.050
# episode 484 | reward: -57.69 | timestamp: 00:02:37 | epsilon: 0.050
# episode 485 | reward: -55.48 | timestamp: 00:02:53 | epsilon: 0.050
# episode 486 | reward: -13.17 | timestamp: 00:03:10 | epsilon: 0.050
# episode 487 | reward: -36.62 | timestamp: 00:03:26 | epsilon: 0.050
# episode 488 | reward: -51.81 | timestamp: 00:03:42 | epsilon: 0.050
# episode 489 | reward: -58.85 | timestamp: 00:03:57 | epsilon: 0.050
# episode 490 | reward: -59.87 | timestamp: 00:04:13 | epsilon: 0.050
# episode 491 | reward: -21.71 | timestamp: 00:04:30 | epsilon: 0.050
# episode 492 | reward: -17.22 | timestamp: 00:04:46 | epsilon: 0.050
# episode 493 | reward: -70.39 | timestamp: 00:05:02 | epsilon: 0.050
# episode 494 | reward: -31.51 | timestamp: 00:05:19 | epsilon: 0.050
# episode 495 | reward: -61.69 | timestamp: 00:05:35 | epsilon: 0.050
# episode 496 | reward: -55.48 | timestamp: 00:05:51 | epsilon: 0.050
# episode 497 | reward: -53.41 | timestamp: 00:06:07 | epsilon: 0.050
# episode 498 | reward: -69.80 | timestamp: 00:06:23 | epsilon: 0.050
# episode 499 | reward: -47.37 | timestamp: 00:06:40 | epsilon: 0.050
# episode 500 | reward: -44.98 | timestamp: 00:06:57 | epsilon: 0.050
# episode 501 | reward: 13.56 | timestamp: 00:07:13 | epsilon: 0.050
# episode 502 | reward: 17.12 | timestamp: 00:07:30 | epsilon: 0.050
# episode 503 | reward: -31.37 | timestamp: 00:07:47 | epsilon: 0.050
# episode 504 | reward: 41.89 | timestamp: 00:08:03 | epsilon: 0.050
# episode 505 | reward: -10.22 | timestamp: 00:08:20 | epsilon: 0.050
# episode 506 | reward: 28.47 | timestamp: 00:08:37 | epsilon: 0.050
# episode 507 | reward: -63.82 | timestamp: 00:08:53 | epsilon: 0.050
# episode 508 | reward: -49.15 | timestamp: 00:09:10 | epsilon: 0.050
# episode 509 | reward: -32.20 | timestamp: 00:09:26 | epsilon: 0.050
# episode 510 | reward: -10.11 | timestamp: 00:09:42 | epsilon: 0.050
# episode 511 | reward: -21.49 | timestamp: 00:09:58 | epsilon: 0.050
# episode 512 | reward: -47.04 | timestamp: 00:10:15 | epsilon: 0.050
# episode 513 | reward: -47.37 | timestamp: 00:10:31 | epsilon: 0.050
# episode 514 | reward: -51.30 | timestamp: 00:10:47 | epsilon: 0.050
# episode 515 | reward: -58.06 | timestamp: 00:11:03 | epsilon: 0.050
# episode 516 | reward: 3.81 | timestamp: 00:11:19 | epsilon: 0.050
# episode 517 | reward: -37.73 | timestamp: 00:11:35 | epsilon: 0.050
# episode 518 | reward: -28.06 | timestamp: 00:11:51 | epsilon: 0.050
# episode 519 | reward: -69.58 | timestamp: 00:12:06 | epsilon: 0.050
# episode 520 | reward: -46.67 | timestamp: 00:12:22 | epsilon: 0.050
# episode 521 | reward: -18.43 | timestamp: 00:12:39 | epsilon: 0.050
# episode 522 | reward: -81.13 | timestamp: 00:12:55 | epsilon: 0.050
# episode 523 | reward: -44.25 | timestamp: 00:13:11 | epsilon: 0.050
# episode 524 | reward: -15.13 | timestamp: 00:13:27 | epsilon: 0.050
# episode 525 | reward: -29.63 | timestamp: 00:13:44 | epsilon: 0.050
# episode 526 | reward: -48.91 | timestamp: 00:14:00 | epsilon: 0.050
# episode 527 | reward: -22.26 | timestamp: 00:14:16 | epsilon: 0.050
# episode 528 | reward: -44.25 | timestamp: 00:14:33 | epsilon: 0.050
# episode 529 | reward: -66.57 | timestamp: 00:14:49 | epsilon: 0.050
# episode 530 | reward: -71.43 | timestamp: 00:15:05 | epsilon: 0.050
# episode 531 | reward: -73.51 | timestamp: 00:15:22 | epsilon: 0.050
# episode 532 | reward: -72.41 | timestamp: 00:15:38 | epsilon: 0.050
# episode 533 | reward: -59.73 | timestamp: 00:15:55 | epsilon: 0.050
# episode 534 | reward: -65.64 | timestamp: 00:16:11 | epsilon: 0.050
# episode 535 | reward: -65.84 | timestamp: 00:16:28 | epsilon: 0.050
# episode 536 | reward: -27.67 | timestamp: 00:16:45 | epsilon: 0.050
# episode 537 | reward: -15.49 | timestamp: 00:17:01 | epsilon: 0.050
# episode 538 | reward: -47.18 | timestamp: 00:17:17 | epsilon: 0.050
# episode 539 | reward: -15.49 | timestamp: 00:17:33 | epsilon: 0.050
# episode 540 | reward: -44.03 | timestamp: 00:17:50 | epsilon: 0.050
# episode 541 | reward: -3.23 | timestamp: 00:18:06 | epsilon: 0.050
# episode 542 | reward: -40.00 | timestamp: 00:18:23 | epsilon: 0.050
# episode 543 | reward: 14.81 | timestamp: 00:18:39 | epsilon: 0.050
# episode 544 | reward: -8.47 | timestamp: 00:18:56 | epsilon: 0.050
# episode 545 | reward: -40.63 | timestamp: 00:19:13 | epsilon: 0.050
# episode 546 | reward: -31.60 | timestamp: 00:19:29 | epsilon: 0.050
# episode 547 | reward: -53.33 | timestamp: 00:19:45 | epsilon: 0.050
# episode 548 | reward: -60.53 | timestamp: 00:20:01 | epsilon: 0.050
# episode 549 | reward: -26.69 | timestamp: 00:20:18 | epsilon: 0.050
# episode 550 | reward: -30.04 | timestamp: 00:20:34 | epsilon: 0.050
# episode 551 | reward: -45.34 | timestamp: 00:20:51 | epsilon: 0.050
# episode 552 | reward: -48.63 | timestamp: 00:21:07 | epsilon: 0.050
# episode 553 | reward: -17.53 | timestamp: 00:21:23 | epsilon: 0.050
# episode 554 | reward: -62.26 | timestamp: 00:21:39 | epsilon: 0.050
# episode 555 | reward: -42.86 | timestamp: 00:21:55 | epsilon: 0.050
# episode 556 | reward: -24.46 | timestamp: 00:22:11 | epsilon: 0.050
# episode 557 | reward: -33.58 | timestamp: 00:22:28 | epsilon: 0.050
# episode 558 | reward: -72.88 | timestamp: 00:22:44 | epsilon: 0.050
# episode 559 | reward: -72.11 | timestamp: 00:23:00 | epsilon: 0.050
# episode 560 | reward: -29.75 | timestamp: 00:23:16 | epsilon: 0.050
# episode 561 | reward: -50.66 | timestamp: 00:23:32 | epsilon: 0.050
# episode 562 | reward: -37.50 | timestamp: 00:23:48 | epsilon: 0.050
# episode 563 | reward: -27.84 | timestamp: 00:24:04 | epsilon: 0.050
# episode 564 | reward: -23.30 | timestamp: 00:24:21 | epsilon: 0.050
# episode 565 | reward: -61.54 | timestamp: 00:24:38 | epsilon: 0.050
# episode 566 | reward: -18.15 | timestamp: 00:24:54 | epsilon: 0.050
# episode 567 | reward: -44.08 | timestamp: 00:25:10 | epsilon: 0.050
# episode 568 | reward: -78.87 | timestamp: 00:25:26 | epsilon: 0.050
# episode 569 | reward: -61.54 | timestamp: 00:25:42 | epsilon: 0.050
# episode 570 | reward: -11.50 | timestamp: 00:25:59 | epsilon: 0.050
# episode 571 | reward: -25.32 | timestamp: 00:26:15 | epsilon: 0.050
# episode 572 | reward: -28.81 | timestamp: 00:26:31 | epsilon: 0.050
# episode 573 | reward: -11.66 | timestamp: 00:26:47 | epsilon: 0.050
# episode 574 | reward: 1.05 | timestamp: 00:27:03 | epsilon: 0.050
# episode 575 | reward: -46.54 | timestamp: 00:27:19 | epsilon: 0.050
# episode 576 | reward: -63.93 | timestamp: 00:27:35 | epsilon: 0.050
# episode 577 | reward: -78.10 | timestamp: 00:27:50 | epsilon: 0.050
# episode 578 | reward: -76.90 | timestamp: 00:28:06 | epsilon: 0.050
# episode 579 | reward: -56.35 | timestamp: 00:28:21 | epsilon: 0.050
# episode 580 | reward: -30.23 | timestamp: 00:28:38 | epsilon: 0.050
# episode 581 | reward: -42.24 | timestamp: 00:28:54 | epsilon: 0.050
# episode 582 | reward: -47.71 | timestamp: 00:29:10 | epsilon: 0.050
# episode 583 | reward: -67.53 | timestamp: 00:29:26 | epsilon: 0.050
# episode 584 | reward: -55.93 | timestamp: 00:29:42 | epsilon: 0.050
# episode 585 | reward: 0.81 | timestamp: 00:29:57 | epsilon: 0.050
# episode 586 | reward: -75.78 | timestamp: 00:30:13 | epsilon: 0.050
# episode 587 | reward: -66.44 | timestamp: 00:30:29 | epsilon: 0.050
# episode 588 | reward: -27.90 | timestamp: 00:30:44 | epsilon: 0.050
# episode 589 | reward: -45.69 | timestamp: 00:30:59 | epsilon: 0.050
# episode 590 | reward: -25.17 | timestamp: 00:31:15 | epsilon: 0.050
# episode 591 | reward: -22.33 | timestamp: 00:31:31 | epsilon: 0.050
# episode 592 | reward: -14.89 | timestamp: 00:31:47 | epsilon: 0.050
# episode 593 | reward: -47.37 | timestamp: 00:32:02 | epsilon: 0.050
# episode 594 | reward: -76.43 | timestamp: 00:32:17 | epsilon: 0.050
# episode 595 | reward: 1.12 | timestamp: 00:32:33 | epsilon: 0.050
# episode 596 | reward: -64.63 | timestamp: 00:32:48 | epsilon: 0.050
# episode 597 | reward: -49.10 | timestamp: 00:33:04 | epsilon: 0.050
# episode 598 | reward: -35.29 | timestamp: 00:33:20 | epsilon: 0.050
# episode 599 | reward: -27.08 | timestamp: 00:33:36 | epsilon: 0.050
# episode 600 | reward: -63.82 | timestamp: 00:33:52 | epsilon: 0.050
# episode 601 | reward: -35.59 | timestamp: 00:34:08 | epsilon: 0.050
# episode 602 | reward: -8.50 | timestamp: 00:34:25 | epsilon: 0.050
# episode 603 | reward: -10.39 | timestamp: 00:34:41 | epsilon: 0.050
# episode 604 | reward: -25.93 | timestamp: 00:34:56 | epsilon: 0.050
# episode 605 | reward: -31.74 | timestamp: 00:35:13 | epsilon: 0.050
# episode 606 | reward: -73.86 | timestamp: 00:35:29 | epsilon: 0.050
# episode 607 | reward: 5.08 | timestamp: 00:35:45 | epsilon: 0.050
# episode 608 | reward: -58.62 | timestamp: 00:36:00 | epsilon: 0.050
# episode 609 | reward: -18.24 | timestamp: 00:36:17 | epsilon: 0.050
# episode 610 | reward: -44.88 | timestamp: 00:36:33 | epsilon: 0.050
# episode 611 | reward: -30.92 | timestamp: 00:36:49 | epsilon: 0.050
# episode 612 | reward: -32.20 | timestamp: 00:37:05 | epsilon: 0.050
# episode 613 | reward: -51.46 | timestamp: 00:37:22 | epsilon: 0.050
# episode 614 | reward: -47.02 | timestamp: 00:37:38 | epsilon: 0.050
# episode 615 | reward: -10.51 | timestamp: 00:37:54 | epsilon: 0.050
# episode 616 | reward: -73.05 | timestamp: 00:38:11 | epsilon: 0.050
# episode 617 | reward: -76.43 | timestamp: 00:38:27 | epsilon: 0.050
# episode 618 | reward: -32.38 | timestamp: 00:38:43 | epsilon: 0.050
# episode 619 | reward: -37.70 | timestamp: 00:38:59 | epsilon: 0.050
# episode 620 | reward: -87.63 | timestamp: 00:39:07 | epsilon: 0.050
# episode 621 | reward: -23.59 | timestamp: 00:39:23 | epsilon: 0.050
# episode 622 | reward: -57.14 | timestamp: 00:39:39 | epsilon: 0.050
# episode 623 | reward: -61.27 | timestamp: 00:39:55 | epsilon: 0.050
# episode 624 | reward: -40.77 | timestamp: 00:40:11 | epsilon: 0.050
# episode 625 | reward: 17.65 | timestamp: 00:40:27 | epsilon: 0.050
# episode 626 | reward: -37.96 | timestamp: 00:40:42 | epsilon: 0.050
# episode 627 | reward: 11.50 | timestamp: 00:40:58 | epsilon: 0.050
# episode 628 | reward: -51.49 | timestamp: 00:41:15 | epsilon: 0.050
# episode 629 | reward: 4.03 | timestamp: 00:41:31 | epsilon: 0.050
# episode 630 | reward: -84.19 | timestamp: 00:41:38 | epsilon: 0.050
# episode 631 | reward: -27.48 | timestamp: 00:41:54 | epsilon: 0.050
# episode 632 | reward: -65.65 | timestamp: 00:42:10 | epsilon: 0.050
# episode 633 | reward: -13.04 | timestamp: 00:42:27 | epsilon: 0.050
# episode 634 | reward: -60.00 | timestamp: 00:42:42 | epsilon: 0.050
# episode 635 | reward: -33.82 | timestamp: 00:42:58 | epsilon: 0.050
# episode 636 | reward: -14.47 | timestamp: 00:43:14 | epsilon: 0.050
# episode 637 | reward: 5.26 | timestamp: 00:43:30 | epsilon: 0.050
# episode 638 | reward: -33.85 | timestamp: 00:43:46 | epsilon: 0.050
# episode 639 | reward: 46.85 | timestamp: 00:44:02 | epsilon: 0.050
# episode 640 | reward: -65.99 | timestamp: 00:44:18 | epsilon: 0.050
# episode 641 | reward: -31.03 | timestamp: 00:44:35 | epsilon: 0.050
# episode 642 | reward: -40.63 | timestamp: 00:44:52 | epsilon: 0.050
# episode 643 | reward: -67.39 | timestamp: 00:45:09 | epsilon: 0.050
# episode 644 | reward: -52.53 | timestamp: 00:45:25 | epsilon: 0.050
# episode 645 | reward: 16.61 | timestamp: 00:45:41 | epsilon: 0.050
# episode 646 | reward: -44.44 | timestamp: 00:45:58 | epsilon: 0.050
# episode 647 | reward: 0.65 | timestamp: 00:46:14 | epsilon: 0.050
# episode 648 | reward: 27.52 | timestamp: 00:46:31 | epsilon: 0.050
# episode 649 | reward: -32.14 | timestamp: 00:46:47 | epsilon: 0.050
# episode 650 | reward: -62.55 | timestamp: 00:47:03 | epsilon: 0.050
# episode 651 | reward: -12.75 | timestamp: 00:47:20 | epsilon: 0.050
# episode 652 | reward: -8.82 | timestamp: 00:47:36 | epsilon: 0.050
# episode 653 | reward: -36.80 | timestamp: 00:47:52 | epsilon: 0.050
# episode 654 | reward: -27.59 | timestamp: 00:48:09 | epsilon: 0.050
# episode 655 | reward: -69.39 | timestamp: 00:48:25 | epsilon: 0.050
# episode 656 | reward: -79.59 | timestamp: 00:48:42 | epsilon: 0.050
# episode 657 | reward: -51.56 | timestamp: 00:48:58 | epsilon: 0.050
# episode 658 | reward: -29.53 | timestamp: 00:49:14 | epsilon: 0.050
# episode 659 | reward: -61.67 | timestamp: 00:49:30 | epsilon: 0.050
# episode 660 | reward: -61.27 | timestamp: 00:49:46 | epsilon: 0.050
# episode 661 | reward: -1.36 | timestamp: 00:50:02 | epsilon: 0.050
# episode 662 | reward: -8.09 | timestamp: 00:50:18 | epsilon: 0.050
# episode 663 | reward: -50.50 | timestamp: 00:50:34 | epsilon: 0.050
# episode 664 | reward: -33.82 | timestamp: 00:50:50 | epsilon: 0.050
# episode 665 | reward: -32.84 | timestamp: 00:51:05 | epsilon: 0.050
# episode 666 | reward: 0.37 | timestamp: 00:51:22 | epsilon: 0.050
# episode 667 | reward: -8.54 | timestamp: 00:51:39 | epsilon: 0.050
# episode 668 | reward: -23.84 | timestamp: 00:51:56 | epsilon: 0.050
# episode 669 | reward: -70.49 | timestamp: 00:52:12 | epsilon: 0.050
# episode 670 | reward: -31.30 | timestamp: 00:52:28 | epsilon: 0.050
# episode 671 | reward: -16.97 | timestamp: 00:52:45 | epsilon: 0.050
# episode 672 | reward: -12.28 | timestamp: 00:53:01 | epsilon: 0.050
# episode 673 | reward: -77.35 | timestamp: 00:53:17 | epsilon: 0.050
# episode 674 | reward: -10.71 | timestamp: 00:53:33 | epsilon: 0.050
# episode 675 | reward: -72.14 | timestamp: 00:53:49 | epsilon: 0.050
# episode 676 | reward: 2.41 | timestamp: 00:54:06 | epsilon: 0.050
# episode 677 | reward: -13.36 | timestamp: 00:54:22 | epsilon: 0.050
# episode 678 | reward: -29.03 | timestamp: 00:54:39 | epsilon: 0.050
# episode 679 | reward: -40.85 | timestamp: 00:54:55 | epsilon: 0.050
# episode 680 | reward: -30.80 | timestamp: 00:55:11 | epsilon: 0.050
# episode 681 | reward: -71.33 | timestamp: 00:55:27 | epsilon: 0.050
# episode 682 | reward: -21.82 | timestamp: 00:55:44 | epsilon: 0.050
# episode 683 | reward: -44.44 | timestamp: 00:55:59 | epsilon: 0.050
# episode 684 | reward: 1.01 | timestamp: 00:56:16 | epsilon: 0.050
# episode 685 | reward: -50.35 | timestamp: 00:56:32 | epsilon: 0.050
# episode 686 | reward: -57.58 | timestamp: 00:56:49 | epsilon: 0.050
# episode 687 | reward: -55.27 | timestamp: 00:57:05 | epsilon: 0.050
# episode 688 | reward: -76.03 | timestamp: 00:57:22 | epsilon: 0.050
# episode 689 | reward: -53.33 | timestamp: 00:57:38 | epsilon: 0.050
# episode 690 | reward: -62.46 | timestamp: 00:57:54 | epsilon: 0.050
# episode 691 | reward: -53.18 | timestamp: 00:58:10 | epsilon: 0.050
# episode 692 | reward: -61.40 | timestamp: 00:58:27 | epsilon: 0.050
# episode 693 | reward: -74.82 | timestamp: 00:58:43 | epsilon: 0.050
# episode 694 | reward: 6.62 | timestamp: 00:58:59 | epsilon: 0.050
# episode 695 | reward: -65.40 | timestamp: 00:59:14 | epsilon: 0.050
# episode 696 | reward: -35.94 | timestamp: 00:59:31 | epsilon: 0.050
# episode 697 | reward: -63.86 | timestamp: 00:59:47 | epsilon: 0.050
# episode 698 | reward: -7.06 | timestamp: 01:00:03 | epsilon: 0.050
# episode 699 | reward: -1.10 | timestamp: 01:00:20 | epsilon: 0.050
# episode 700 | reward: -37.09 | timestamp: 01:00:36 | epsilon: 0.050
# episode 701 | reward: -40.98 | timestamp: 01:00:52 | epsilon: 0.050
# episode 702 | reward: -52.21 | timestamp: 01:01:09 | epsilon: 0.050
# episode 703 | reward: -78.18 | timestamp: 01:01:26 | epsilon: 0.050
# episode 704 | reward: -62.96 | timestamp: 01:01:42 | epsilon: 0.050
# episode 705 | reward: -31.27 | timestamp: 01:01:59 | epsilon: 0.050
# episode 706 | reward: -43.45 | timestamp: 01:02:15 | epsilon: 0.050
# episode 707 | reward: 20.37 | timestamp: 01:02:32 | epsilon: 0.050
# episode 708 | reward: -57.45 | timestamp: 01:02:49 | epsilon: 0.050
# ...
# episode 2768 | reward: -61.78 | timestamp: 10:08:25 | epsilon: 0.050
# episode 2769 | reward: -0.00 | timestamp: 10:08:42 | epsilon: 0.050
# episode 2770 | reward: -71.06 | timestamp: 10:08:58 | epsilon: 0.050
# episode 2771 | reward: -36.75 | timestamp: 10:09:14 | epsilon: 0.050
# episode 2772 | reward: -68.48 | timestamp: 10:09:31 | epsilon: 0.050
# episode 2773 | reward: -78.12 | timestamp: 10:09:48 | epsilon: 0.050
# episode 2774 | reward: -50.70 | timestamp: 10:10:03 | epsilon: 0.050
# episode 2775 | reward: 50.00 | timestamp: 10:10:19 | epsilon: 0.050
# episode 2776 | reward: -65.52 | timestamp: 10:10:36 | epsilon: 0.050
# episode 2777 | reward: -56.38 | timestamp: 10:10:53 | epsilon: 0.050
# episode 2778 | reward: -49.32 | timestamp: 10:11:08 | epsilon: 0.050
# episode 2779 | reward: -101.39 | timestamp: 10:11:21 | epsilon: 0.050
# episode 2780 | reward: -38.72 | timestamp: 10:11:38 | epsilon: 0.050
# episode 2781 | reward: -2.72 | timestamp: 10:11:54 | epsilon: 0.050
# episode 2782 | reward: 36.99 | timestamp: 10:12:11 | epsilon: 0.050
# episode 2783 | reward: -49.61 | timestamp: 10:12:27 | epsilon: 0.050
# episode 2784 | reward: 1.05 | timestamp: 10:12:43 | epsilon: 0.050
# episode 2785 | reward: -28.33 | timestamp: 10:12:59 | epsilon: 0.050
# episode 2786 | reward: -77.56 | timestamp: 10:13:16 | epsilon: 0.050
# episode 2787 | reward: -24.66 | timestamp: 10:13:32 | epsilon: 0.050
# episode 2788 | reward: -50.82 | timestamp: 10:13:48 | epsilon: 0.050
# episode 2789 | reward: -64.41 | timestamp: 10:14:04 | epsilon: 0.050
# episode 2790 | reward: 38.18 | timestamp: 10:14:21 | epsilon: 0.050
# episode 2791 | reward: -44.65 | timestamp: 10:14:37 | epsilon: 0.050
# episode 2792 | reward: -55.06 | timestamp: 10:14:53 | epsilon: 0.050
# episode 2793 | reward: -35.48 | timestamp: 10:15:09 | epsilon: 0.050
# episode 2794 | reward: -66.67 | timestamp: 10:15:25 | epsilon: 0.050
# episode 2795 | reward: 60.71 | timestamp: 10:15:41 | epsilon: 0.050
# episode 2796 | reward: -36.84 | timestamp: 10:15:57 | epsilon: 0.050
# episode 2797 | reward: -72.44 | timestamp: 10:16:13 | epsilon: 0.050
# episode 2798 | reward: -66.91 | timestamp: 10:16:29 | epsilon: 0.050
# episode 2799 | reward: -52.38 | timestamp: 10:16:45 | epsilon: 0.050
# episode 2800 | reward: -75.61 | timestamp: 10:17:02 | epsilon: 0.050
# episode 2801 | reward: -61.81 | timestamp: 10:17:17 | epsilon: 0.050
# episode 2802 | reward: -63.82 | timestamp: 10:17:34 | epsilon: 0.050
# episode 2803 | reward: -33.58 | timestamp: 10:17:50 | epsilon: 0.050
# episode 2804 | reward: -42.75 | timestamp: 10:18:06 | epsilon: 0.050
# episode 2805 | reward: -33.33 | timestamp: 10:18:22 | epsilon: 0.050
# episode 2806 | reward: -42.18 | timestamp: 10:18:38 | epsilon: 0.050
# episode 2807 | reward: -24.34 | timestamp: 10:18:55 | epsilon: 0.050
# episode 2808 | reward: -67.53 | timestamp: 10:19:11 | epsilon: 0.050
# episode 2809 | reward: -47.54 | timestamp: 10:19:26 | epsilon: 0.050
# episode 2810 | reward: -35.06 | timestamp: 10:19:42 | epsilon: 0.050
# episode 2811 | reward: -9.42 | timestamp: 10:19:58 | epsilon: 0.050
# episode 2812 | reward: -70.20 | timestamp: 10:20:14 | epsilon: 0.050
# episode 2813 | reward: 6.19 | timestamp: 10:20:31 | epsilon: 0.050
# episode 2814 | reward: -80.07 | timestamp: 10:20:47 | epsilon: 0.050
# episode 2815 | reward: -38.46 | timestamp: 10:21:03 | epsilon: 0.050
# episode 2816 | reward: -9.77 | timestamp: 10:21:19 | epsilon: 0.050
# episode 2817 | reward: -68.64 | timestamp: 10:21:35 | epsilon: 0.050
# episode 2818 | reward: -16.06 | timestamp: 10:21:51 | epsilon: 0.050
# episode 2819 | reward: -53.74 | timestamp: 10:22:07 | epsilon: 0.050
# episode 2820 | reward: -26.05 | timestamp: 10:22:23 | epsilon: 0.050
# episode 2821 | reward: -47.18 | timestamp: 10:22:39 | epsilon: 0.050
# episode 2822 | reward: -57.65 | timestamp: 10:22:55 | epsilon: 0.050
# episode 2823 | reward: 5.43 | timestamp: 10:23:11 | epsilon: 0.050
# episode 2824 | reward: -61.13 | timestamp: 10:23:27 | epsilon: 0.050
# episode 2825 | reward: -30.69 | timestamp: 10:23:43 | epsilon: 0.050
# episode 2826 | reward: -30.92 | timestamp: 10:24:00 | epsilon: 0.050
# episode 2827 | reward: -56.95 | timestamp: 10:24:16 | epsilon: 0.050
# episode 2828 | reward: -66.22 | timestamp: 10:24:32 | epsilon: 0.050
# episode 2829 | reward: -20.15 | timestamp: 10:24:47 | epsilon: 0.050
# episode 2830 | reward: -61.40 | timestamp: 10:25:03 | epsilon: 0.050
# episode 2831 | reward: -46.03 | timestamp: 10:25:19 | epsilon: 0.050
# episode 2832 | reward: 17.09 | timestamp: 10:25:35 | epsilon: 0.050
# episode 2833 | reward: 15.38 | timestamp: 10:25:51 | epsilon: 0.050
# episode 2834 | reward: -20.14 | timestamp: 10:26:08 | epsilon: 0.050
# episode 2835 | reward: -47.69 | timestamp: 10:26:24 | epsilon: 0.050
# episode 2836 | reward: -4.93 | timestamp: 10:26:40 | epsilon: 0.050
# episode 2837 | reward: -24.40 | timestamp: 10:26:56 | epsilon: 0.050
# episode 2838 | reward: -16.97 | timestamp: 10:27:12 | epsilon: 0.050
# episode 2839 | reward: -31.03 | timestamp: 10:27:29 | epsilon: 0.050
# episode 2840 | reward: -10.34 | timestamp: 10:27:44 | epsilon: 0.050
# episode 2841 | reward: -27.27 | timestamp: 10:28:00 | epsilon: 0.050
# episode 2842 | reward: -45.34 | timestamp: 10:28:16 | epsilon: 0.050
# episode 2843 | reward: -76.51 | timestamp: 10:28:32 | epsilon: 0.050
# episode 2844 | reward: -54.68 | timestamp: 10:28:48 | epsilon: 0.050
# episode 2845 | reward: 70.04 | timestamp: 10:29:04 | epsilon: 0.050
# episode 2846 | reward: -33.75 | timestamp: 10:29:21 | epsilon: 0.050
# episode 2847 | reward: -80.39 | timestamp: 10:29:37 | epsilon: 0.050
# episode 2848 | reward: -66.04 | timestamp: 10:29:53 | epsilon: 0.050
# episode 2849 | reward: -79.93 | timestamp: 10:30:09 | epsilon: 0.050
# episode 2850 | reward: -33.80 | timestamp: 10:30:25 | epsilon: 0.050
# episode 2851 | reward: -58.06 | timestamp: 10:30:40 | epsilon: 0.050
# episode 2852 | reward: -57.96 | timestamp: 10:30:56 | epsilon: 0.050
# episode 2853 | reward: -30.00 | timestamp: 10:31:11 | epsilon: 0.050
# episode 2854 | reward: -11.11 | timestamp: 10:31:27 | epsilon: 0.050
# episode 2855 | reward: -51.89 | timestamp: 10:31:44 | epsilon: 0.050
# episode 2856 | reward: -34.85 | timestamp: 10:32:00 | epsilon: 0.050
# episode 2857 | reward: -35.19 | timestamp: 10:32:16 | epsilon: 0.050
# episode 2858 | reward: -8.40 | timestamp: 10:32:32 | epsilon: 0.050
# episode 2859 | reward: -34.98 | timestamp: 10:32:48 | epsilon: 0.050
# episode 2860 | reward: -47.37 | timestamp: 10:33:05 | epsilon: 0.050
# episode 2861 | reward: -26.05 | timestamp: 10:33:21 | epsilon: 0.050
# episode 2862 | reward: -23.08 | timestamp: 10:33:37 | epsilon: 0.050
# episode 2863 | reward: -23.81 | timestamp: 10:33:54 | epsilon: 0.050
# episode 2864 | reward: -73.51 | timestamp: 10:34:10 | epsilon: 0.050
# episode 2865 | reward: -15.13 | timestamp: 10:34:25 | epsilon: 0.050
# episode 2866 | reward: -28.08 | timestamp: 10:34:42 | epsilon: 0.050
# episode 2867 | reward: -11.11 | timestamp: 10:34:58 | epsilon: 0.050
# episode 2868 | reward: -42.95 | timestamp: 10:35:14 | epsilon: 0.050
# episode 2869 | reward: -74.60 | timestamp: 10:35:30 | epsilon: 0.050
# episode 2870 | reward: -2.10 | timestamp: 10:35:46 | epsilon: 0.050
# episode 2871 | reward: -34.85 | timestamp: 10:36:02 | epsilon: 0.050
# episode 2872 | reward: -1.82 | timestamp: 10:36:17 | epsilon: 0.050
# episode 2873 | reward: -43.71 | timestamp: 10:36:33 | epsilon: 0.050
# episode 2874 | reward: 16.61 | timestamp: 10:36:49 | epsilon: 0.050
# episode 2875 | reward: -35.37 | timestamp: 10:37:05 | epsilon: 0.050
# episode 2876 | reward: -62.33 | timestamp: 10:37:21 | epsilon: 0.050
# episode 2877 | reward: 35.92 | timestamp: 10:37:37 | epsilon: 0.050
# episode 2878 | reward: -60.14 | timestamp: 10:37:52 | epsilon: 0.050
# episode 2879 | reward: -127.38 | timestamp: 10:38:04 | epsilon: 0.050
# episode 2880 | reward: -16.13 | timestamp: 10:38:20 | epsilon: 0.050
# episode 2881 | reward: -53.74 | timestamp: 10:38:36 | epsilon: 0.050
# episode 2882 | reward: -10.85 | timestamp: 10:38:52 | epsilon: 0.050
# episode 2883 | reward: -69.42 | timestamp: 10:39:08 | epsilon: 0.050
# episode 2884 | reward: -41.75 | timestamp: 10:39:25 | epsilon: 0.050
# episode 2885 | reward: -25.00 | timestamp: 10:39:41 | epsilon: 0.050
# episode 2886 | reward: -41.18 | timestamp: 10:39:57 | epsilon: 0.050
# episode 2887 | reward: -35.38 | timestamp: 10:40:13 | epsilon: 0.050
# episode 2888 | reward: -34.26 | timestamp: 10:40:29 | epsilon: 0.050
# episode 2889 | reward: -18.15 | timestamp: 10:40:44 | epsilon: 0.050
# episode 2890 | reward: -23.59 | timestamp: 10:41:01 | epsilon: 0.050
# episode 2891 | reward: -22.22 | timestamp: 10:41:16 | epsilon: 0.050
# episode 2892 | reward: -31.45 | timestamp: 10:41:32 | epsilon: 0.050
# episode 2893 | reward: -23.32 | timestamp: 10:41:48 | epsilon: 0.050
# episode 2894 | reward: -40.56 | timestamp: 10:42:04 | epsilon: 0.050
# episode 2895 | reward: -9.43 | timestamp: 10:42:20 | epsilon: 0.050
# episode 2896 | reward: -21.71 | timestamp: 10:42:36 | epsilon: 0.050
# episode 2897 | reward: -19.30 | timestamp: 10:42:52 | epsilon: 0.050
# episode 2898 | reward: -38.18 | timestamp: 10:43:08 | epsilon: 0.050
# episode 2899 | reward: -20.42 | timestamp: 10:43:24 | epsilon: 0.050
# episode 2900 | reward: -53.42 | timestamp: 10:43:40 | epsilon: 0.050
# episode 2901 | reward: -38.65 | timestamp: 10:43:57 | epsilon: 0.050
# episode 2902 | reward: -77.05 | timestamp: 10:44:13 | epsilon: 0.050
# episode 2903 | reward: -54.55 | timestamp: 10:44:28 | epsilon: 0.050
# episode 2904 | reward: -67.64 | timestamp: 10:44:44 | epsilon: 0.050
# episode 2905 | reward: -52.03 | timestamp: 10:45:00 | epsilon: 0.050
# episode 2906 | reward: -34.93 | timestamp: 10:45:16 | epsilon: 0.050
# episode 2907 | reward: -52.38 | timestamp: 10:45:32 | epsilon: 0.050
# episode 2908 | reward: -19.87 | timestamp: 10:45:49 | epsilon: 0.050
# episode 2909 | reward: -62.50 | timestamp: 10:46:05 | epsilon: 0.050
# episode 2910 | reward: -18.37 | timestamp: 10:46:21 | epsilon: 0.050
# episode 2911 | reward: -43.89 | timestamp: 10:46:37 | epsilon: 0.050
# episode 2912 | reward: -18.44 | timestamp: 10:46:53 | epsilon: 0.050
# episode 2913 | reward: -29.53 | timestamp: 10:47:09 | epsilon: 0.050
# episode 2914 | reward: -72.60 | timestamp: 10:47:25 | epsilon: 0.050
# episode 2915 | reward: -52.23 | timestamp: 10:47:42 | epsilon: 0.050
# episode 2916 | reward: -49.53 | timestamp: 10:47:58 | epsilon: 0.050
# episode 2917 | reward: -62.07 | timestamp: 10:48:14 | epsilon: 0.050
# episode 2918 | reward: -54.37 | timestamp: 10:48:30 | epsilon: 0.050
# episode 2919 | reward: -55.22 | timestamp: 10:48:46 | epsilon: 0.050
# episode 2920 | reward: -0.00 | timestamp: 10:49:03 | epsilon: 0.050
# episode 2921 | reward: -53.80 | timestamp: 10:49:20 | epsilon: 0.050
# episode 2922 | reward: -27.84 | timestamp: 10:49:35 | epsilon: 0.050
# episode 2923 | reward: -47.74 | timestamp: 10:49:51 | epsilon: 0.050
# episode 2924 | reward: -59.11 | timestamp: 10:50:07 | epsilon: 0.050
# episode 2925 | reward: -59.85 | timestamp: 10:50:23 | epsilon: 0.050
# episode 2926 | reward: 12.73 | timestamp: 10:50:39 | epsilon: 0.050
# episode 2927 | reward: -74.21 | timestamp: 10:50:56 | epsilon: 0.050
# episode 2928 | reward: -3.47 | timestamp: 10:51:12 | epsilon: 0.050
# episode 2929 | reward: -57.52 | timestamp: 10:51:28 | epsilon: 0.050
# episode 2930 | reward: -21.82 | timestamp: 10:51:44 | epsilon: 0.050
# episode 2931 | reward: -36.17 | timestamp: 10:52:00 | epsilon: 0.050
# episode 2932 | reward: 1.05 | timestamp: 10:52:16 | epsilon: 0.050
# episode 2933 | reward: -139.17 | timestamp: 10:52:31 | epsilon: 0.050
# episode 2934 | reward: -65.52 | timestamp: 10:52:47 | epsilon: 0.050
# episode 2935 | reward: 3.45 | timestamp: 10:53:02 | epsilon: 0.050
# episode 2936 | reward: -80.00 | timestamp: 10:53:18 | epsilon: 0.050
# episode 2937 | reward: -26.91 | timestamp: 10:53:34 | epsilon: 0.050
# episode 2938 | reward: -81.82 | timestamp: 10:53:50 | epsilon: 0.050
# episode 2939 | reward: -19.86 | timestamp: 10:54:07 | epsilon: 0.050
# episode 2940 | reward: -32.26 | timestamp: 10:54:23 | epsilon: 0.050
# episode 2941 | reward: -79.31 | timestamp: 10:54:40 | epsilon: 0.050
# episode 2942 | reward: -79.02 | timestamp: 10:54:56 | epsilon: 0.050
# episode 2943 | reward: 8.91 | timestamp: 10:55:13 | epsilon: 0.050
# episode 2944 | reward: -37.28 | timestamp: 10:55:29 | epsilon: 0.050
# episode 2945 | reward: -33.58 | timestamp: 10:55:45 | epsilon: 0.050
# episode 2946 | reward: -12.75 | timestamp: 10:56:00 | epsilon: 0.050
# episode 2947 | reward: -19.73 | timestamp: 10:56:16 | epsilon: 0.050
# episode 2948 | reward: -19.09 | timestamp: 10:56:33 | epsilon: 0.050
# episode 2949 | reward: -53.18 | timestamp: 10:56:49 | epsilon: 0.050
# episode 2950 | reward: -23.53 | timestamp: 10:57:06 | epsilon: 0.050
# episode 2951 | reward: -77.27 | timestamp: 10:57:22 | epsilon: 0.050
# episode 2952 | reward: -50.18 | timestamp: 10:57:38 | epsilon: 0.050
# episode 2953 | reward: -34.38 | timestamp: 10:57:54 | epsilon: 0.050
# episode 2954 | reward: -62.62 | timestamp: 10:58:11 | epsilon: 0.050
# episode 2955 | reward: -31.74 | timestamp: 10:58:27 | epsilon: 0.050
# episode 2956 | reward: -39.07 | timestamp: 10:58:43 | epsilon: 0.050
# episode 2957 | reward: -31.45 | timestamp: 10:58:59 | epsilon: 0.050
# episode 2958 | reward: -51.22 | timestamp: 10:59:15 | epsilon: 0.050
# episode 2959 | reward: -55.02 | timestamp: 10:59:31 | epsilon: 0.050
# episode 2960 | reward: -72.97 | timestamp: 10:59:47 | epsilon: 0.050
# episode 2961 | reward: -53.62 | timestamp: 11:00:04 | epsilon: 0.050
# episode 2962 | reward: -55.93 | timestamp: 11:00:20 | epsilon: 0.050
# episode 2963 | reward: -22.03 | timestamp: 11:00:36 | epsilon: 0.050
# episode 2964 | reward: 67.24 | timestamp: 11:00:53 | epsilon: 0.050
# episode 2965 | reward: -46.56 | timestamp: 11:01:09 | epsilon: 0.050
# episode 2966 | reward: -21.43 | timestamp: 11:01:25 | epsilon: 0.050
# episode 2967 | reward: -41.78 | timestamp: 11:01:41 | epsilon: 0.050
# episode 2968 | reward: -65.40 | timestamp: 11:01:58 | epsilon: 0.050
# episode 2969 | reward: -56.36 | timestamp: 11:02:13 | epsilon: 0.050
# episode 2970 | reward: -67.95 | timestamp: 11:02:29 | epsilon: 0.050
# episode 2971 | reward: -27.15 | timestamp: 11:02:45 | epsilon: 0.050
# episode 2972 | reward: -42.31 | timestamp: 11:03:02 | epsilon: 0.050
# episode 2973 | reward: -55.47 | timestamp: 11:03:18 | epsilon: 0.050
# episode 2974 | reward: -75.44 | timestamp: 11:03:35 | epsilon: 0.050
# episode 2975 | reward: -6.98 | timestamp: 11:03:52 | epsilon: 0.050
# episode 2976 | reward: -82.58 | timestamp: 11:04:08 | epsilon: 0.050
# episode 2977 | reward: -31.37 | timestamp: 11:04:25 | epsilon: 0.050
# episode 2978 | reward: -61.90 | timestamp: 11:04:41 | epsilon: 0.050
# episode 2979 | reward: -10.51 | timestamp: 11:04:56 | epsilon: 0.050
# episode 2980 | reward: -12.28 | timestamp: 11:05:12 | epsilon: 0.050
# episode 2981 | reward: -21.97 | timestamp: 11:05:29 | epsilon: 0.050
# episode 2982 | reward: -59.46 | timestamp: 11:05:45 | epsilon: 0.050
# episode 2983 | reward: -32.14 | timestamp: 11:06:01 | epsilon: 0.050
# episode 2984 | reward: 16.88 | timestamp: 11:06:17 | epsilon: 0.050
# episode 2985 | reward: -34.93 | timestamp: 11:06:33 | epsilon: 0.050
# episode 2986 | reward: -70.50 | timestamp: 11:06:50 | epsilon: 0.050
# episode 2987 | reward: -45.87 | timestamp: 11:07:07 | epsilon: 0.050
# episode 2988 | reward: -32.20 | timestamp: 11:07:23 | epsilon: 0.050
# episode 2989 | reward: -62.59 | timestamp: 11:07:39 | epsilon: 0.050
# episode 2990 | reward: -63.86 | timestamp: 11:07:55 | epsilon: 0.050
# episode 2991 | reward: -49.53 | timestamp: 11:08:12 | epsilon: 0.050
# episode 2992 | reward: -16.17 | timestamp: 11:08:29 | epsilon: 0.050
# episode 2993 | reward: -30.50 | timestamp: 11:08:44 | epsilon: 0.050
# episode 2994 | reward: 6.31 | timestamp: 11:09:01 | epsilon: 0.050
# episode 2995 | reward: -23.34 | timestamp: 11:09:18 | epsilon: 0.050
# episode 2996 | reward: -52.86 | timestamp: 11:09:34 | epsilon: 0.050
# episode 2997 | reward: -22.39 | timestamp: 11:09:51 | epsilon: 0.050
# episode 2998 | reward: -49.82 | timestamp: 11:10:07 | epsilon: 0.050
# episode 2999 | reward: -25.09 | timestamp: 11:10:22 | epsilon: 0.050

# %%
agent_evaluation(dqn_agent, "dqn_agent.pt")
# Out:
# /var/folders/jp/2bd2v8t94j7b19234wnwph_h0000gn/T/ipykernel_46219/3364544582.py:33: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   agent.q_net.load_state_dict(torch.load(model_path, map_location=device))
# episode 1: reward = -77.44
# episode 2: reward = -73.60
# episode 3: reward = -79.52
# episode 4: reward = -78.18
# episode 5: reward = -60.13
# episode 6: reward = -38.36
# episode 7: reward = -80.20
# episode 8: reward = -57.93
# episode 9: reward = -78.49
# episode 10: reward = -77.19
# avg reward : -70.10417838236636

# %%
def record_episode(agent_class, model_path, output_video="output_video.mp4"):

    env = gym.make("CarRacing-v3", render_mode="rgb_array")
    stacker = frame_stacker(4)
    frames = []

    agent = agent_class()
    agent.q_net.load_state_dict(torch.load(model_path, map_location=device))
    agent.q_net.to(device)
    agent.q_net.eval()

    obs, info = env.reset()
    state = stacker.reset(obs)

    done = False
    total_reward = 0
    step = 0

    while not done:
        with torch.no_grad():
            
            state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
            action = agent.q_net(state_tensor).argmax().item()

        obs, reward, terminated, truncated, info = env.step(actions[action])
        frame = env.render()
        frames.append(frame)

        done = terminated or truncated
        state = stacker.step(obs)
        total_reward += reward
        step += 1

    env.close()


    imageio.mimsave(output_video, frames, fps=30)

# %%
record_episode(dqn_agent, model_path="dqn_agent.pt", output_video="dqn_episode.mp4")
# Out:
# /var/folders/jp/2bd2v8t94j7b19234wnwph_h0000gn/T/ipykernel_46219/2176824271.py:14: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   agent.q_net.load_state_dict(torch.load(model_path, map_location=device))
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).

# %% [markdown]
# ref:
#
# A2 code
